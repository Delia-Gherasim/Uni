# %%
1+1
# Out:
# 2

# %%
numerical_approx(44/13, digits=1000)
# Out:
# 3....

# %%
x=SR.var('x')

# %%
p1=(x+1)^2
p1
# Out:
# (x + 1)^2

# %%
p1.expand()
# Out:
# x^2 + 2*x + 1

# %%
15/6
# Out:
# 5/2

# %%
15./6
# Out:
# 2.50000000000000

# %%
numerical_approx(15/6, digits=3)
# Out:
# 2.50

# %%
f(x) = x^2 - 5*x + e^x
plot(f(x), -10000, 10000)
# Out:
# verbose 0 (3839: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 93 points.
# verbose 0 (3839: plot.py, generate_plot_points) Last error message: 'math range error'
# Graphics object consisting of 1 graphics primitive

# %%
1/2
# Out:
# 1/2

# %%
exp(1)
# Out:
# e

# %%
numerical_approx(exp(1))
# Out:
# 2.71828182845905

# %%
sqrt(3.)
# Out:
# 1.73205080756888

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
sin(1)
# Out:
# sin(1)

# %%
numerical_approx(sin(1))
# Out:
# 0.841470984807897

# %%
var('x')
p=(x^2+2*x-1)^3*(x^2-2)
p.expand()
# Out:
# x^8 + 6*x^7 + 7*x^6 - 16*x^5 - 27*x^4 + 14*x^3 + 17*x^2 - 12*x + 2

# %%
factorize(x^8-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-57e45cb69b48> in <module>
# ----> 1 factorize(x**Integer(8)-Integer(1))
#
# NameError: name 'factorize' is not defined

# %%
factor(x^8-1)
# Out:
# (x^4 + 1)*(x^2 + 1)*(x + 1)*(x - 1)

# %%
p=x^8-1
p.factor()
# Out:
# (x^4 + 1)*(x^2 + 1)*(x + 1)*(x - 1)

# %%
factor(2*x^2/(x^3-1) + (3*x/(x^2-1)))
# Out:
# (5*x^2 + 5*x + 3)*x/((x^2 + x + 1)*(x + 1)*(x - 1))

# %%
p=sin(x)^2 + cos(x)^2

# %%
(sin(x)^2+cos(x)^2).trig_simplify()
# Out:
# 1

# %%
p.trig_simplify()
# Out:
# 1

# %%
f=exp(x)+log(x)
f.subs(x=0)
# Out:
# -Infinity

# %%
eq=x^2-4*x+3 == 0
solve(eq, x)
# Out:
# [x == 3, x == 1]

# %%
var('y')
eq2 = x^2*y+2*y-x==0
solve(eq2, y)
# Out:
# [y == x/(x^2 + 2)]

# %%
solve(eq2, x)
# Out:
# [x == -1/2*(sqrt(-8*y^2 + 1) - 1)/y, x == 1/2*(sqrt(-8*y^2 + 1) + 1)/y]

# %%
eq3=x-cos(x)==0
find_root(x-cos(x), -1, 1)
# Out:
# 0.7390851332151607

# %%
eq4=x^5-3*x^3-1==0
find_root(eq4, -2, 2)
# Out:
# 1.7823087800458832

# %%
find_root(eq4, -1, 1)
# Out:
# -0.741813930486773

# %%
find_root(eq4, -2, -1)
# Out:
# -1.6687775925403805

# %%
eq5=4*x+3*y==10
eq6=3*x-y==1
syst=[eq5, eq6]
solve(syst, x, y)
# Out:
# [[x == 1, y == 2]]

# %%
g=exp(x)-sin(x)
diff(g(x), x)
# Out:
# -cos(x) + e^x

# %%
integrate(g(x), x)
# Out:
# cos(x) + e^x

# %%
integral_numerical(g(x), -1, 1)
# Out:
# (2.3504023872876028, 2.609470847500631e-14)

# %%
limit(sin(x)/x, x=0)
# Out:
# 1

# %%
limit((cos(x)+1)/(x-pi), x=pi)
# Out:
# 0

# %%
f(x) = sin(x)
plot(f(x), -100, 100)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x) = 1/(x-1)
plot(f(x), 0, 2, ymax=10, ymin=-10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x) = 1/(x-1)
plot(f(x), 0, 2, ymax=10, ymin=-10, detect_poles=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('t')
x=2-t^2
y=t-t^3
parametric_plot((x, y), (t, -2, 2), ymax=2, ymin=-2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=cos(t)
y=sin(t)
parametric_plot((x,y), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x, y')
implicit_plot(x^2-2*x*y-y^2==1, (-5, 5), (-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
implicit_plot(x^2+y^2==1, (-2, 2), (-2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x, y')
f(x, y) = x^2+y^2
plot3d(x^2+y^2, (-2, 2), (-2, 2))
# Out:
# Graphics3d Object
