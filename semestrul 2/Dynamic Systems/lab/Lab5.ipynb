# %%
# 1
x, y = var('x y')
eq = solve([2*x - x^2 - x*y, -y + x*y], x, y)
eq
# Out:
# [[x == 0, y == 0], [x == 2, y == 0], [x == 1, y == 1]]

# %%
x, y = var('x y')
f=(2*x-x^2-x*y, -y + x*y)
jac = jacobian(f, ((x, y)))
jac
# Out:
# [-2*x - y + 2           -x]
# [           y        x - 1]

# %%
A1=jac.subs(x=0, y=0)
A1
# Out:
# [ 2  0]
# [ 0 -1]

# %%
A2=jac.subs(x=2, y=0)
A2
# Out:
# [-2 -2]
# [ 0  1]

# %%
A3=jac.subs(x=1, y=1)
A3
# Out:
# [-1 -1]
# [ 1  0]

# %%
A1.eigenvalues()
# Out:
# [-1, 2]

# %%
A2.eigenvalues()
# Out:
# [-2, 1]

# %%
A3.eigenvalues()
# Out:
# [-1/2*I*sqrt(3) - 1/2, 1/2*I*sqrt(3) - 1/2]

# %%
x,y = var('x y')
f=(2*x-x^2-x*y, -y + x*y)
plot_vector_field((f[0], f[1]), (x, -1, 2.2), (y, -1, 1.2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot_vector_field((f[0], f[1]), (x, -0.2, 0.2), (y, -0.2, 0.2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot_vector_field((f[0], f[1]), (x, 0.9, 1.1), (y, 0.9, 1.1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# ex 3
x, y = var('x y')
f1 = 
f2 = func('')

# %%
x = var('x')
y = function('y')(x)
sol = desolve(diff(y, x) == -4*sin(x)/y, y)
(-8) * sol - 8*cos(x)
# Out:
# y(x)^2 - 8*cos(x) == -8*_C

# %%
x, y = var('x y')
H = function('H')(x, y)
H(x, y) = y^2-8*cos(x)

diff(H, x) * y - 4*diff(H, y)*sin(x) == 0
# Out:
# (x, y) |--> 0 == 0

# %%
contour_plot(H, (-5, 5), (-5, 5), fill=false, contours=20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# ex 4
f=(x-x*y, -0.3*y+0.3*x*y)
f
# Out:
# (-x*y + x, 0.300000000000000*x*y - 0.300000000000000*y)

# %%
time = srange(0, 10, 0.1)
p=plot_vector_field((f[0], f[1]), (x, 0, 16), (y, 0, 7))
p
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
for ics in [(0.01, 0.5), (2.1, 0.01), (1.5, 0.01)]:
    sol = desolve_odeint(f, ics, time, [x, y])
    p+=line(zip(sol[:,0], sol[:,1]))
p
# Out:
# Graphics object consisting of 7 graphics primitives
