# %%
var('t')
diff(sin(t), t)
# Out:
# cos(t)

# %%
var('t')
diff(sin(t), t, 4)
# Out:
# sin(t)

# %%
x = sin(t)
diff(x, t, 4) - x
# Out:
# 0

# %%
x = cos(t)
diff(x, t, 4) - x
# Out:
# 0

# %%
x = sinh(t)
diff(x, t, 4) - x
# Out:
# 0

# %%
x = cosh(t)
diff(x, t, 4) - x
# Out:
# 0

# %%
x=function('x')(t)
eq=diff(x, t, 2) + x == 0
desolve(eq, x)
# Out:
# _K2*cos(t) + _K1*sin(t)

# %%
# 4x'' +8x'+5x=0
#char eq: 4r^2 + 8r + 5 = 0
eq=4*diff(x,t,2)+8*diff(x,t)+5*x==0
desolve(eq, x)
# Out:
# (_K2*cos(1/2*t) + _K1*sin(1/2*t))*e^(-t)

# %%
eq=diff(x,t,2)-3*diff(x,t)+2*x==0
desolve(eq, x)
# Out:
# _K1*e^(2*t) + _K2*e^t

# %%
x=function('x')(t)
eq7 = diff(x, t, 2) + x
sol7= desolve(eq7, x, ics=[pi/2, 1, -2])
plot(sol7, ymin=-10, ymax=10, xmin=-10, xmax=10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
(sqrt(5)*cos(t-arctan(1/2))).trig_simplify()
# Out:
# 2*cos(t) + sin(t)

# %%
eq8 = 4*diff(x, t, 2) + 8*diff(x, t) + 5*x
sol8 = desolve(eq8, x, ics=[0, 0, 0.5])
# Out:
# e^(-t)*sin(1/2*t)

# %%
plot(sol8, ymin=-100, ymax=100, xmin=-100, xmax=100)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq8 = diff(x, t, 2) - 3 * diff(x, t) + 2 * x
sol8 = desolve(eq8, x, ics = [0, 2, 3])
plot(sol8, -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq9_1 = diff(x, t, 2) + 5*x
eq9_2 = diff(x, t, 2) + t*x
eq9_3 = diff(x, t, 2) + (t^5)*x

sol1=desolve(eq9_1, x)
sol2=desolve(eq9_2, x, contrib_ode=true)
sol3=desolve(eq9_3, x, contrib_ode=true)
sol1, sol2, sol3
# Out:
# (_K2*cos(sqrt(5)*t) + _K1*sin(sqrt(5)*t),
#  [x(t) == _K1*sqrt(t)*bessel_J(1/3, 2/3*t^(3/2)) + _K2*sqrt(t)*bessel_Y(1/3, 2/3*t^(3/2))],
#  [x(t) == _K1*sqrt(t)*bessel_J(-1/7, 2/7*t^(7/2)) + _K2*sqrt(t)*bessel_Y(-1/7, 2/7*t^(7/2))])

# %%
plot(bessel_J(3, t), -5, 5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq10 = diff(x, t, 2) + x
sol10 = desolve(eq10, x, ics = [0, 0, pi, 0])
sol10
# Out:
# r57*sin(t)

# %%
eq11 = eq10
sol11=desolve(eq11, x, ics = [0, 0, 1, 0])
sol11
# Out:
# 0

# %%
plot(sol11)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq12 = diff(x, t, 2) + x == 1
sol12 = desolve(eq12, x, ics = [0, 0, pi, 0])
sol12
# Out:
# []

# %%
eq13 = diff(x, t) + x == 15
sol13 = desolve(eq13, x)
sol13
# Out:
# (_C + 15*e^t)*e^(-t)

# %%
sol13.subs(_C=0)
# Out:
# 15

# %%
eq14 = diff(x, t) + x == 2* e^t -7*e^(-3*t)
sol14 = desolve(eq14, x)
sol14
sol14 = sol14.subs(_C=0)
sol14.factor()
# Out:
# 1/2*(2*e^(4*t) + 7)*e^(-3*t)

# %%
eq15 = diff(x, t) + x == -t^2+3*t-7
sol15 = desolve(eq15, x)
sol15
# Out:
# -((t^2 - 2*t + 2)*e^t - 3*(t - 1)*e^t - _C + 7*e^t)*e^(-t)

# %%
sol15 = sol15.subs(_C=0)
sol15.factor()
# Out:
# -t^2 + 5*t - 12

# %%
eq16 = diff(x, t) + x == sin(t) + 3*cos(t)
sol16 = desolve(eq16, x)
sol16
# Out:
# 1/2*(3*(cos(t) + sin(t))*e^t - (cos(t) - sin(t))*e^t + 2*_C)*e^(-t)

# %%
sol16 = sol16.subs(_C=0)
sol16 = sol16.factor()
sol16
# Out:
# cos(t) + 2*sin(t)

# %%
eq17 = diff(x, t) + x == sin(t)
sol17 = desolve(eq17, x)
sol17
# Out:
# -1/2*((cos(t) - sin(t))*e^t - 2*_C)*e^(-t)

# %%
sol17 = sol17.subs(_C=0).factor()
sol17
# Out:
# -1/2*cos(t) + 1/2*sin(t)

# %%
eq18 = diff(x, t) + x == 3 * cos(t)
sol18 = desolve(eq18, x)
sol18
# Out:
# 1/2*(3*(cos(t) + sin(t))*e^t + 2*_C)*e^(-t)

# %%
sol18.subs(_C=0).factor()
# Out:
# 3/2*cos(t) + 3/2*sin(t)
